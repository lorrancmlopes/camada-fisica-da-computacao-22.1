# %% [markdown]
# Camada Física da Computação 2020/2
#
# Aula 14  - **Prática em Fourier**
#
# Rodrigo Carareto rodrigoc5@insper.edu.br

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from scipy.fftpack import fft, fftshift

# %%
def generateSin(freq, time, fs):
    n = time*fs #numero de pontos
    x = np.linspace(0.0, time, n)  # eixo do tempo
    s = np.sin(freq*x*2*np.pi)
    plt.figure()
    plt.plot(x,s)
    return (x, s)

# %%
def calcFFT(signal, fs):
    # https://docs.scipy.org/doc/scipy/reference/tutorial/fftpack.html
    #y  = np.append(signal, np.zeros(len(signal)*fs))
    N  = len(signal)
    T  = 1/fs
    xf = np.linspace(-1.0/(2.0*T), 1.0/(2.0*T), N)
    yf = fft(signal)
    return(xf, fftshift(yf))

# %% [markdown]
# ## Propriedades dos sinais

# %%
fs  = 200   # pontos por segundo (frequência de amostragem)
A   = 1.5   # Amplitude
F   = 1     # Hz
T   = 4     # Tempo em que o seno será gerado
t   = np.linspace(-T/2,T/2,T*fs)

# %% [markdown]
# # Prática em Fourier

# %% [markdown]
# ## Senoide única
#
#  - Gere uma senoide de 5Hz
#
# ### Para analisar :
#
#  - Exiba o sinal no tempo e o Fourier do mesmo (módulo e fase)
#  - Analíse a composição espectal desse sinal.
#  - Calcule a banda do sinal

# %%
x, y = generateSin(5,T,fs)
plt.figure()
plt.plot(t, y, '.-')

X, Y = calcFFT(y,fs)
plt.figure()
plt.stem(X,np.abs(Y))#A stem plot plots vertical lines at each x location from the baseline to y, and places a marker there.


plt.figure()
plt.stem(X,np.imag(Y))
# Out:
# <ipython-input-5-397075716edd>:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.abs(Y))#A stem plot plots vertical lines at each x location from the baseline to y, and places a marker there.
# <ipython-input-5-397075716edd>:11: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.imag(Y))
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Senoides
#
#  - Gere duas senoide de mesma amplitude e frequência 5Hz e 8Hz
#
# ### Para analisar :
#
#  - Exiba o sinal no tempo e o Fourier do mesmo (módulo)
#  - Analíse a composição espectal desse sinal.

# %%
x1, y1 = generateSin(5,T,fs)
x2, y2 = generateSin(6,T,fs)
x3, y3 = generateSin(7,T,fs)
x4, y4 = generateSin(8,T,fs)
y=y1 + 2*y2 + 3*y3 + y4
plt.figure()
plt.plot(t, y, '.-')

X, Y = calcFFT(y,fs)
plt.figure()
plt.stem(X,np.abs(Y))
plt.xlim(-15, 15)

plt.figure()
plt.stem(X,np.imag(Y))
plt.xlim(-15, 15)
# Out:
# <ipython-input-6-756daf93706a>:11: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.abs(Y))
# <ipython-input-6-756daf93706a>:15: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.imag(Y))
# (-15.0, 15.0)

# %% [markdown]
# ## Onda Quadrada nivel DC = 0
#
#  - Gere uma onda quadrada em torno do eixo X de amplitude 3 e frequência 1Hz
#      - dica : signal.square
#
# ### Para analisar :
#
#  - Exiba o sinal no tempo e o Fourier do mesmo (módulo e fase)
#  - Analíse a composição espectal desse sinal.

# %%
y = signal.square(2 * np.pi * 1 * t, 0.5)
plt.figure()
plt.plot(t, y, '.-')

X, Y = calcFFT(y,fs)
plt.figure()
plt.stem(X,np.abs(Y))

plt.figure()
plt.stem(X,np.imag(Y))
# Out:
# <ipython-input-7-484b5293a979>:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.abs(Y))
# <ipython-input-7-484b5293a979>:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.imag(Y))
# <StemContainer object of 3 artists>

# %% [markdown]
# ## Pulso
#
#  - Gere um pulso em torno da origem de duração (1.5s, 1s, 0.5s, 0.025s)
#      - dica : signal.square
#
# ### Para analisar
#
#  - Exiba o sinal no tempo e o Fourier dos sinais (módulo )
#  - Analíse a composição espectal dos pulsos (com duração distintas)
#  - Calcule as bandas dos sinais

# %%
y1 = signal.square(2 * np.pi * 1/3 * (t+.75), 0.5)
y2 = signal.square(2 * np.pi * .5 * (t+.5), 0.5)
y3 = signal.square(2 * np.pi * 1 * (t+.25), 0.5)
y4 = signal.square(2 * np.pi * 20 * (t+.05/4), 0.5)

for x in range(len(t)):
    if(t[x]>.5 or t[x]<-.5):
        y2[x]=0
    if(t[x]>.25 or t[x]<-.25):
        y3[x]=0
    if(t[x]>.0125 or t[x]<-.0125):
        y4[x]=0

#seleciona 1
y=y3
#######

plt.figure()
plt.plot(t, y, '.-')

X, Y = calcFFT(y,fs)
plt.figure()
plt.stem(X,np.abs(Y))
plt.xlim(-20,20)

plt.figure()
plt.stem(X,np.imag(Y))
plt.xlim(-20,20)
# Out:
# <ipython-input-8-7a0588085110>:23: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.abs(Y))
# <ipython-input-8-7a0588085110>:27: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(X,np.imag(Y))
# (-20.0, 20.0)

# %% [markdown]
# ## FFT PYTHON
# Vamos testar o algoritmo FFT do python e a função de localizar picos. Para isso, inicialmente, grave um arquivo de audio de poucos segundos. Em seguida, importe e execute esse audio. Altere a taxa de amostragem e veja o que ocorre. Tente entender.

# %%
pip install soundfile
# Out:
# Requirement already satisfied: soundfile in c:\users\lorra\anaconda3\lib\site-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in c:\users\lorra\anaconda3\lib\site-packages (from soundfile) (1.14.0)
# Requirement already satisfied: pycparser in c:\users\lorra\anaconda3\lib\site-packages (from cffi>=1.0->soundfile) (2.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
from suaBibSignal import *
import numpy as np
import sounddevice as sd
import matplotlib.pyplot as plt
import soundfile as sf


#leituara do arquivo audio
fs = 44100   # taxqa de amostagem (sample rate)
sd.default.samplerate = fs
sd.default.channels = 1
audio, samplerate = sf.read('gravacao.wav')
yAudio = audio
samplesAudio = len(yAudio)
sd.play(audio)
sd.wait()

# %%
# fs  = 200   # pontos por segundo (frequência de amostragem)
# A   = 1   # Amplitude
# F   = num    # Hz
# T   = 4     # Tempo em que o seno será gerado
# x, y = generateSin(F,T,fs)

# %% [markdown]
# Plot o gráfico do sinal no tempo.

# %%
plt.plot(yAudio[500:800])
plt.grid()

# %%
plt.title('Oi no tempo')
# Out:
# Text(0.5, 1.0, 'Oi no tempo')

# %% [markdown]
# Obtenha transformada de Fourier do arquivo, mostre o gráfico dos módulos.

# %%
X, Y = calcFFT(yAudio, samplerate)
plt.figure("Fourier Audio")
plt.plot(X, np.abs(Y))
plt.grid()
plt.title('Oi Frequencia')
# plt.xlim(400,600)
# plt.ylim(0,0.175)
# Out:
# Text(0.5, 1.0, 'Oi Frequencia')

# %% [markdown]
# Obtenha as 5 frequências mais presentes na composição do sinal.

# %%
pip install peakutils
# Out:
# Requirement already satisfied: peakutils in c:\users\lorra\anaconda3\lib\site-packages (1.3.3)
# Requirement already satisfied: numpy in c:\users\lorra\anaconda3\lib\site-packages (from peakutils) (1.21.2)
# Requirement already satisfied: scipy in c:\users\lorra\anaconda3\lib\site-packages (from peakutils) (1.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
x = np.array([(i[0] for i in np.abs(Y))])
x
# Out:
# array([<generator object <genexpr> at 0x000001B19F05C120>], dtype=object)

# %%
import peakutils
index = peakutils.indexes(x, thres=0.8, min_dist=300)
print("index de picos {}" .format(index))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-3338c73a7875> in <module>
#       1 import peakutils
# ----> 2 index = peakutils.indexes(x, thres=0.8, min_dist=300)
#       3 print("index de picos {}" .format(index))
#
# ~\anaconda3\lib\site-packages\peakutils\peak.py in indexes(y, thres, min_dist, thres_abs)
#      41
#      42     if not thres_abs:
# ---> 43         thres = thres * (np.max(y) - np.min(y)) + np.min(y)
#      44
#      45     min_dist = int(min_dist)
#
# TypeError: unsupported operand type(s) for -: 'generator' and 'generator'

# %%
for freq in X[index]:
    print("freq de pico sao {}" .format(freq))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-a45b3535b21c> in <module>
#       1 import peakutils
# ----> 2 index = peakutils.indexes(x, thres=0.8, min_dist=20)
#       3 print("index de picos {}" .format(index))
#       4 for freq in X[index]:
#       5     print("freq de pico sao {}" .format(freq))
#
# ~\anaconda3\lib\site-packages\peakutils\peak.py in indexes(y, thres, min_dist, thres_abs)
#      41
#      42     if not thres_abs:
# ---> 43         thres = thres * (np.max(y) - np.min(y)) + np.min(y)
#      44
#      45     min_dist = int(min_dist)
#
# TypeError: unsupported operand type(s) for -: 'generator' and 'generator'
